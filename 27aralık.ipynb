# %% [markdown]
# <a href="https://colab.research.google.com/github/serrabaysal/auto-ml-course-notes/blob/main/27aral%C4%B1k.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Federatif Öğrenme ve AutoML Entegrasyonu
# 1. Neden Federatif öğrenme: Mevzuat, verinin taşınmasını yasaklar.maliyet ağ yükü ve enerji israfı.
# 2. Veri siloları(data silos):farklı kurumlar kendi değerli verilerine sahiptir.küçük bir yerde eğitilen veriler başka bir yerde.
# 3. ham veriyi başka bir merkeze çeken bir dağıtık öğrenme protolüdür.
# 4. Verinin lokalliği,broadcast(yayılım),yerel güncellemeler,birleştrirme
# 5. ML ve    Federatif öğrenme arasındaki farklar
# *  ham veri aktarılıyor ,model gradyanları      aktarılıyor
# *  veri sızıntısı ihtimali, gizlilik
# *  işlem gücü süper bilgisayarlar, dağıtık bir computing
# 6. İŞ AKIŞI
# 7. ADIM 1: KONFİGÜRASYON: Parametre seçimi
# 8. ADIM 2: SERVER: mevut modelin ağırlıklarını sıcak bir başlangıçla gönderir.
# 9. ADIM 3:YEREL EĞİTİM  Her client kendi verilerini eğitir.
# 10. ADIM 4:GÜNCELLEME Sadece ağırlıkları gönderiyorum.
# 11. ADIM 5: GÜVENLİ BİRLEŞTİRME : sunucu binlerce veriyi birleştirerek ağırlıklı güncelleme
# FED agr veri heterojen olacak şekilde seçer.
# 12. Federatif öğrenme ön bir hazırlık gerekiyor.Fakat veri gizliliği açısından çok iyi.
# 13. FedAvg:Federate Averaging:Hedef tüm istemcilerdeki kaybı yani loss'u minimize etmek.
# *   Rasgele seçimi, AutoML seçimi,
# 14. Yatay Federatif Öğrenme: her sütun ve satır birbirine denk fakat farklı semptomlara ait.
# 15. Dikey Federatif Öğrenme: banka kredisi, e-ticaret veri kullanımı.
# 16. FedProx : Heterojenik Öğrenme : daha yavaş ve daha iyi öğrenmeyi otomatik olarak optimize ediyor.
# 17. FedNova : İstemcilerin güncellemlerini normalizasyonun gücü, manuel ayarlama zor.
# 18. Güvenli Agregasyon: Her istemci rasgele sayı olarak bakar.
# 19. Diferansiyel Gizlilik(DP): Gürültü ekleme ara katmana gauss gürültüsü ekleme
# gizlilik bütçesi: gizlilik artar.
# 20. Homomorfik şifreleme: client ve bölüm olarak en az işlem gücü gerektiren işlemi seçer.
# 21. Hiperparametre Optimizasyonu:
# 22. FedNAS Çalışma Prensibi: İstemciler hangi verilerin beraber dağılımını belirler.
# 23. FedHPO: Hiperparametre otomasyonu
# GlobalHPO,LocalHPO,Bayesian Opt.
# 24. Kişiselleştirilmiş AutoML:

# %% [markdown]
# # AutoML
# 1. flwr.dev :java,python,API ile kullanılır.federatif öğrenme için.
# 2. TFF: Tensorflow Federated
# * fonksiyonel programlama
# * imperatif paradigma:
# 3. pysyft: veriyi görmemeyi sağlayan bir katman
# 4. FedML: Research to Production
# 5. Model Zehirlenmesi: (Model Poisoning):
# Modelin belirli bir sınıfta hata yapmaya zorlamaktadır.Tüm clientların düzgün veri göndermesini kontrol etmek gerekir.
# 6. Bizans Hata Toleransı: Aykırı değerler atılır.Medyan alınabilir.En küçük ve en düşük değerlerin atılmasını ister.
# 7. Veri sızıntısı: gradyanlardan veri sızıntısı veri geri döndürülemez.
# 8. Merkeziyetsiz P2P Federatif Öğrenme
