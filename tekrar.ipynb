# %% [markdown]
# <a href="https://colab.research.google.com/github/serrabaysal/auto-ml-course-notes/blob/main/tekrar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AUTOML
# 1. Machine learning süreçlerini azaltan bir süreçtir.
# 2. Zaman tasarrufu sağlar. Daha akıllı yöntemleri kullanmayı amaçlar.
# 3. CPU'lu bir cihaza ihtiyaç olabilir.
# 4. **Hiperparametre** optimizasyonu diye bir kavram ortaya çıktı.
# 5. Grid-SearchCV :arama uzayı büyüdükçe yavaş çalışır. Senin verdiğin arama uzayındaki sonuçları çalıştırıyordu.
# 6. RandomizedSearchCV: Grid'e göre çok iyi, Bayes optimizasyonuna göre kötü
# 7. Bayesian Optimization: Önceki sonuçlardan öğrendiklerini kullanır. akıllı bir denetimi var. Optunayı kullanıyorduk.
# 8. TP Optuna Bayes kullanıyor. Tree structured parzen estimator
# 9. Population based Training (PBT)
# En iyi sonuca ulaşmamızı sağlar.,

# %% [markdown]
# #  TABULAR REGRESYON VE SINIFLANDIRMA CSV
# 1. Veri temizleme teknikleri
# Ölçeklendirme(scaling)
# MİnMaxScaler= 0 ve 1 aykırı değere karşı direnci az
# 2. Auto-sklearn:sıcak başlangıç meta learning sayesinde.
# ensemble yapabilirsin. Bayes optimizasyonunu kullanır. Modelin hangi hiperparametreleriyle olabileceğini seçer.
# 3. TPOT(Genetic Programming)
# çok kullanılan uygulamalrdan bir tanesidir.
# 4. H2O.ai.AutoML:
# 5. küçük veriler: auto-sklearn
# 6. kurumsal big datada: H2O.ai.AutoML

# %% [markdown]
# ## DERİN ÖĞRENME
# 1. Auto-keras: NAS tabanlı. görüntü ve sınıflandırma konusunda çok faydalı.
# 2. Auto-PyTorch: Ensemble:modeller grubunu kullanıyor. auto-keras gibi efficient modelini mesela kullanıyoruz.
# 3. Baseline Model oluşturma
# 4. Model arayacağız, hiperparametreleri değiştirecğiz.
# 5. dengesizse f1 score , veriler dengeliyse f1 score accuracy ile beraber aynı gelmiş olur.

# %% [markdown]
# # NAS(NEUTRAL)
# Reinforcement ve Algoritma AutoML gibi ama teknik farklılıklar var. Aynı kütüphaneleri kullanıyor. Search yaklaşımlarından bir tanesi
# 1. Otomatik makine öğrenme modellerini gerçek dünya problemlerine uygulama sürecini uçtan uca otomatikleştirmeyi amaçlar.
# Geleneksel ML süreçleri şunları gerektirir.
# * Veri ön işleme
# * Özellik mühendisliği
# * Model Seçimi
# * Hiperparametre optimizasyonu
# 2. Denetimli öğrenme kullanıyor ve kontroller kısmı RL'ye öğreniyor

# %% [markdown]
# # RL'ye GİRİŞ
# 1. Hata yaptıkça cezalandıran bir sistem. Ödül-ceza yöntemi var.
# 2. Meta-learning:geçmiş deneyimlerden faydalanarak kullanılan bir sistem.
# 3. Hangi algoritmaların başarılı olacağını seçiyorduk.Sıcak başlangıç
